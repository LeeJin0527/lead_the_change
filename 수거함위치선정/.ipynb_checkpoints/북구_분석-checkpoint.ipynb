# %%
import pandas as pd
import folium
import json

# %%
DeaguSub = pd.read_csv('../data/map/subway.csv', index_col = 0,encoding='cp949')
DeaguSub.rename(columns={'stattion':'Station'}, inplace=True)
DeaguStation = DeaguSub[['Station', '위도', '경도']]
DeaguStation.head()
# Out:
#        Station         위도          경도
# No
# 1           각산  35.868002  128.724166
# 2           교대  35.850095  128.590596
# 3   대곡(정부대구청사)  35.809438  128.512486
# 5           대명  35.839316  128.565379
# 4          대구역  35.876015  128.597282

# %%
m = folium.Map(location=[35.8649155,128.5963041], zoom_start=10, tiles="CartoDB positron")

# %%
df = pd.read_csv('../data/population/북구_인구.csv')
df['dong'] = df['dong'].astype('str')

# %%
geo_data = open('../data/map/북구.json', 'r', encoding='utf-8').read()
geo_data
# Out:
# '{\n    "type": "FeatureCollection",\n    "name": "HangJeongDong_ver202000701",\n    "crs": { "type": "name", "properties": { "name": "urn:ogc:def:crs:OGC:1.3:CRS84" } },\n    "features": [\n{ "type": "Feature", "properties": { "OBJECTID": 686, "adm_nm": "대구광역시 북구 고성동", "adm_cd": "2205051", "adm_cd2": "2723051000", "sidonm": "대구광역시", "sggnm": "북구" }, "geometry": { "type": "MultiPolygon", "coordinates": [ [ [ [ 128.584615339170995, 35.884592886823306 ], [ 128.590243981178816, 35.883400024523304 ], [ 128.588396730842135, 35.877576520549624 ], [ 128.588378794772325, 35.877525407670603 ], [ 128.580171753307837, 35.879078551523371 ], [ 128.580207628925081, 35.879202146774233 ], [ 128.582077250254599, 35.885130682306496 ], [ 128.584615339170995, 35.884592886823306 ] ] ] ] } },\n{ "type": "Feature", "properties": { "OBJECTID": 687, "adm_nm": "대구광역시 북구 칠성동", "adm_cd": "2205052", "adm_cd2": "2723052600", "sidonm": "대구광역시", "sggnm": "북구" }, "geometry": { "type": "MultiPolygon", "coordinates": [ [ [ [ 128.590918762484904, 35.885702926386784 ], [ 128.592953943085604, 35.884497275667599 ], [ 128.594110461026219, 35.883015459051997 ], [ 128.595092961248582, 35.882577809312316 ], [ 128.597204904821012, 35.881746757132078 ], [ 128.597783283501713, 35.881975637813809 ], [ 128.59853000503702, 35.882334914824177 ], [ 128.599633164975359, 35.882961615681964 ], [ 128.599976485930171, 35.883187412076879 ], [ 128.600011332499889, 35.883211160959846 ], [ 128.600206759243946, 35.883379280618094 ], [ 128.601082181697194, 35.884148145316402 ], [ 128.601198217661818, 35.884262516203158 ], [ 128.60214576726375, 35.885854912263397 ], [ 128.602537322148834, 35.882255620872378 ], [ 128.602688808140073, 35.881845211571864 ], [ 128.602862785035597, 35.881373865595521 ], [ 128.603121889422198, 35.880671880395212 ], [ 128.603629573049801, 35.879980251505856 ], [ 128.605056821713845, 35.878107442612915 ], [ 128.605427245550658, 35.877731371562398 ], [ 128.606768870731969, 35.876599996042145 ], [ 128.61032348997179, 35.874896028820494 ], [ 128.609687257446353, 35.874630941885897 ], [ 128.607565459508294, 35.874054841311576 ], [ 128.606173391510708, 35.873831122391231 ], [ 128.605848501286829, 35.873846360732593 ], [ 128.604451395264931, 35.873911879738515 ], [ 128.60347991538876, 35.874083541037066 ], [ 128.601507051867259, 35.874651289239324 ], [ 128.60136171435073, 35.874804946040669 ], [ 128.599141113526912, 35.875464069627412 ], [ 128.594946375242984, 35.875297745352825 ], [ 128.594916650076158, 35.876309776132445 ], [ 128.588378794772325, 35.877525407670603 ], [ 128.588396730842135, 35.877576520549624 ], [ 128.590243981178816, 35.883400024523304 ], [ 128.584615339170995, 35.884592886823306 ], [ 128.585698515909598, 35.886673800852414 ], [ 128.58588889470181, 35.886651873898359 ], [ 128.590918762484904, 35.885702926386784 ] ] ] ] } },\n{ "type": "Feature", "properties": { "OBJECTID": 688, "adm_nm": "대구광역시 북구 침산1동", "adm_cd": "2205055", "adm_cd2": "2723055000", "sidonm": "대구광역시", "sggnm": "북구" }, "geometry": { "type": "MultiPolygon", "coordinates": [ [ [ [ 128.593170724104255, 35.90574943889802 ], [ 128.593339788694266, 35.903829992026374 ], [ 128.593576557915043, 35.901142881790243 ], [ 128.593056121232848, 35.901031206731666 ], [ 128.588076151505931, 35.900530429908883 ], [ 128.58619454682534, 35.895721486168753 ], [ 128.585111857013345, 35.89347690366526 ], [ 128.583582890751075, 35.892179581995805 ], [ 128.583374213147351, 35.89188622369813 ], [ 128.582992218743755, 35.890685887329397 ], [ 128.583136575414898, 35.890380526197632 ], [ 128.583558719446472, 35.889951838077351 ], [ 128.579787766555853, 35.890808635045431 ], [ 128.579329884078504, 35.891306322939698 ], [ 128.577564228371784, 35.893254827499518 ], [ 128.577613940450107, 35.89344793557683 ], [ 128.577992812952715, 35.894676102286859 ], [ 128.579373963446841, 35.899436073360341 ], [ 128.579387812226287, 35.899531560124338 ], [ 128.579156666495066, 35.901312636239112 ], [ 128.579118931943952, 35.901 ...

# %%
folium.Choropleth(
    geo_data=geo_data,
    data=df,
    columns=['dong','count'],
    key_on='feature.properties.adm_cd2',
    fill_color='BuPu',fill_opacity=0.7, line_opacity=0.5,
    legend_name='populations',
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for i in DeaguStation.index:
    sub_lat =  DeaguStation.loc[i,'위도']
    sub_long = DeaguStation.loc[i,'경도']
    
    title = DeaguStation.loc[i,'Station']
    
    #지도에 데이터 찍어서 보여주기
    folium.Circle([sub_lat,sub_long],tooltip = title, color='#000000', fill='crimson', radius = 50).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
