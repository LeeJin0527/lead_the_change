# %%
import pandas as pd
import folium
import json

# %%
DeaguSub = pd.read_csv('../data/map/subway.csv', index_col = 0,encoding='cp949')
DeaguSub.rename(columns={'stattion':'Station'}, inplace=True)
DeaguStation = DeaguSub[['Station', '위도', '경도']]
DeaguStation.head()
# Out:
#        Station         위도          경도
# No
# 1           각산  35.868002  128.724166
# 2           교대  35.850095  128.590596
# 3   대곡(정부대구청사)  35.809438  128.512486
# 5           대명  35.839316  128.565379
# 4          대구역  35.876015  128.597282

# %%
m = folium.Map(location=[35.8649155,128.5963041], zoom_start=10)

# %%
df = pd.read_csv('../data/population/수성구_인구.csv')
df['dong'] = df['dong'].astype('str')

# %%
geo_data = open('../data/map/수성구.json', 'r', encoding='utf-8').read()
geo_data
# Out:
# '{\n    "type": "FeatureCollection",\n    "name": "HangJeongDong_ver202000701",\n    "crs": { "type": "name", "properties": { "name": "urn:ogc:def:crs:OGC:1.3:CRS84" } },\n    "features": [\n{ "type": "Feature", "properties": { "OBJECTID": 709, "adm_nm": "대구광역시 수성구 범어1동", "adm_cd": "2206051", "adm_cd2": "2726051000", "sidonm": "대구광역시", "sggnm": "수성구" }, "geometry": { "type": "MultiPolygon", "coordinates": [ [ [ [ 128.622452936786942, 35.859552967366248 ], [ 128.624207499922846, 35.85937208048297 ], [ 128.626573926865404, 35.859385616094052 ], [ 128.632543920654285, 35.858933511470347 ], [ 128.63226108251078, 35.85853907461204 ], [ 128.631866501021534, 35.856544529789062 ], [ 128.63184200792071, 35.855879515380458 ], [ 128.631929367924812, 35.853733692236425 ], [ 128.632095291698135, 35.853209719497357 ], [ 128.632871077606353, 35.851051515278165 ], [ 128.633063023717398, 35.850525065249009 ], [ 128.632936414271427, 35.85050139323323 ], [ 128.632228951583301, 35.849297370964955 ], [ 128.632136158576401, 35.84854471314933 ], [ 128.632298048147646, 35.847808497039885 ], [ 128.632231864099367, 35.847238610767441 ], [ 128.631105087061684, 35.846403508960179 ], [ 128.630730631767136, 35.84622506580854 ], [ 128.630515206044095, 35.846237835043681 ], [ 128.630404486811216, 35.846477897942137 ], [ 128.630080018881046, 35.84730039233596 ], [ 128.626095952522007, 35.84822855423289 ], [ 128.626153644208216, 35.849283476650278 ], [ 128.625186693638994, 35.850371573073119 ], [ 128.624384747366719, 35.850420969929324 ], [ 128.62388144638345, 35.850451965795031 ], [ 128.62356149018143, 35.850471667848467 ], [ 128.620645414649005, 35.850650067149125 ], [ 128.620691810257512, 35.851301891215535 ], [ 128.62145248185638, 35.859625836497202 ], [ 128.622452936786942, 35.859552967366248 ] ] ] ] } },\n{ "type": "Feature", "properties": { "OBJECTID": 710, "adm_nm": "대구광역시 수성구 범어2동", "adm_cd": "2206052", "adm_cd2": "2726052000", "sidonm": "대구광역시", "sggnm": "수성구" }, "geometry": { "type": "MultiPolygon", "coordinates": [ [ [ [ 128.639054028128498, 35.866253897828145 ], [ 128.639001965975154, 35.865902721563799 ], [ 128.639219035635449, 35.864617760094404 ], [ 128.639683249592508, 35.862553502998622 ], [ 128.640413086927367, 35.859000875616879 ], [ 128.632543920654285, 35.858933511470347 ], [ 128.626573926865404, 35.859385616094052 ], [ 128.626863728037677, 35.860848706220835 ], [ 128.627054683041251, 35.862038478891506 ], [ 128.627096695169485, 35.862300260174528 ], [ 128.627108423996276, 35.862373388353376 ], [ 128.627114421442656, 35.862461937393114 ], [ 128.627116449404866, 35.862491897938 ], [ 128.62715399370984, 35.863046800175077 ], [ 128.627154779166119, 35.863118615569114 ], [ 128.627164108826463, 35.863976041188216 ], [ 128.627166412383218, 35.864188843556107 ], [ 128.627102776816855, 35.867127185663136 ], [ 128.629848462349173, 35.866824202364619 ], [ 128.634770661659871, 35.867507530220173 ], [ 128.635133530772265, 35.867520250477696 ], [ 128.635173444656431, 35.867520152779825 ], [ 128.635378714827482, 35.867504202576761 ], [ 128.635633118556143, 35.867479380500036 ], [ 128.635818854136943, 35.867437556480894 ], [ 128.636304931940799, 35.867259723203659 ], [ 128.63663309043045, 35.86707550902274 ], [ 128.639054028128498, 35.866253897828145 ] ] ] ] } },\n{ "type": "Feature", "properties": { "OBJECTID": 711, "adm_nm": "대구광역시 수성구 범어3동", "adm_cd": "2206053", "adm_cd2": "2726053000", "sidonm": "대구광역시", "sggnm": "수성구" }, "geometry": { "type": "MultiPolygon", "coordinates": [ [ [ [ 128.618588394935358, 35.867810833070287 ], [ 128.619267748277991, 35.867744928152213 ], [ 128.627102776816855, 35.867127185663136 ], [ 128.627166412383218, 35.864188843556107 ], [ 128.627164108826463, 35.863976041188216 ], [ 128.627154779166119, 35.863118615569114 ], [ 128.62715399370984, 35.863046800175077 ], [ 128.627116449404866, 35.862491897938 ], [ 128.627114421442656, 35.862461937393114 ], [ 128.627108423996276, 35.862373388353376 ], [ 128.627096695169485, 35.862300 ...

# %%
folium.Choropleth(
    geo_data=geo_data,
    data=df,
    columns=['dong','count'],
    key_on='feature.properties.adm_cd2',
    fill_color='BuPu',fill_opacity=0.7, line_opacity=0.5,
    legend_name='populations',
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for i in DeaguStation.index:
    sub_lat =  DeaguStation.loc[i,'위도']
    sub_long = DeaguStation.loc[i,'경도']
    
    title = DeaguStation.loc[i,'Station']
    
    #지도에 데이터 찍어서 보여주기
    folium.Circle([sub_lat,sub_long],tooltip = title, color='#000000', fill='crimson', radius = 50).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
