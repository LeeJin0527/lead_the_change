# %%
import pandas as pd
import folium
import json

# %%
Deagusg = pd.read_csv('../data/trash_can/달서구쓰레기통위치.csv', index_col = 0,encoding='cp949')
Deagusg.head()
# Out:
#                         ADDER  OWNER          경도         위도    상태
# No
# 1          대구광역시 달서구 신당동 1973   쓰레기통  128.499459  35.844891  인근좌표
# 2           대구광역시 달서구 장기동 810   쓰레기통  128.528415  35.848494   정좌표
# 3   대구광역시 달서구 달구벌대로 1530(감삼동)   쓰레기통  128.533253  35.848957   정좌표
# 4   대구광역시 달서구 달구벌대로 1676(두류동)   쓰레기통  128.549429  35.854203   정좌표
# 5       대구광역시 달서구 월배로 62(진천동)   쓰레기통  128.521337  35.813283   정좌표

# %%
m = folium.Map(location=[35.8649155,128.5963041],tiles= 'CartoDB positron', zoom_start=10)

# %%
deagumap = open('../data/map/달서구.json', 'r', encoding='utf-8').read()
deagumap = json.loads(deagumap)
folium.GeoJson(deagumap, name='json_data').add_to(m)

# %%
for i in Deagusg.index:
    sub_lat =  Deagusg.loc[i,'위도']
    sub_long = Deagusg.loc[i,'경도']
    
    #title = Deagusg.loc[i,'OWNER']
    
    #지도에 데이터 찍어서 보여주기
    folium.Circle([sub_lat,sub_long],tooltip = "쓰레기", color='#000000', fill='crimson', radius = 50).add_to(m)

# %%
m.save('../data/trash_can/달서구.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
